# %% [markdown]
# ## Exercise 2.01

# %% [markdown]
# First, import all of the libraries that you are going to be using by typing the
# following code:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# The pandas library is used to save the dataset into a DataFrame, matplotlib
# is used for visualization, and NumPy is used in later exercises of this chapter, but
# since the same Notebook will be used, it has been imported here.
#
# Load the circles dataset by using Pandas' read_csv function. Type in the
# following code:

# %%
data = pd.read_csv("circles.csv")
plt.scatter(data.iloc[:,0], data.iloc[:,1])
plt.show()

# %% [markdown]
# The final output is a dataset with two features and 1,500 instances. Here, the dot
# represents a data point (an observation), where the location is marked by the
# values of each of the features of the dataset.
#
# Create a histogram out of one of the two features. Use slicing to select the
# feature that you wish to plot:

# %%
plt.hist(data.iloc[:,0])
plt.show()
